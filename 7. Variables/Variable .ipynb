# %%
name = input("what is your name")
print(name)
name = "shubham"
print(name)
# Out:
# raju
# shubham

# %%
# Length Function
name = "shubham"
length = len(name)
print(length)
# Out:
# 7

# %%
# Type Error
a= 1
b = 'shubham'
print( a+b )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 4
#       2 a= 1
#       3 b = 'shubham'
# ----> 4 print( a+b )
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
# By default input() return string
# concatenation of string and integer is possible
name = input("what is your name")
b = 'shubham'
print( name + b )
# Out:
# 1shubham
